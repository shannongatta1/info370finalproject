# %% [markdown]
# ## Logistic Regression

# %%
# Load libaries
import numpy as np
import pandas as pd
import seaborn as sns # for visualiation
from scipy.stats import ttest_ind # t-tests
import statsmodels.formula.api as smf # linear modeling
import statsmodels.api as sm
import matplotlib.pyplot as plt # plotting
import matplotlib
import altair as alt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegressionCV as lr

# %%
# Load in data
dems = pd.read_csv('../data/dem_with_dummies_renamed.csv').drop(['Unnamed: 0', 'Candidate', 'State'], axis=1)

# %%
dems
# Out:
#       Primary..  Neutral.Endorsements  Yes.Endorsements  No.Endorsements  \
# 0      3.420000                    11                 0                1
# 1      1.740000                    11                 0                1
# 2      3.270000                    11                 0                1
# 3      8.000000                    11                 0                1
# 4     28.980000                    11                 0                1
# 5     54.599998                    11                 1                0
# 6     19.230000                    12                 0                0
# 7     80.769997                    12                 0                0
# 8     39.560001                    12                 0                0
# 9     60.439999                    12                 0                0
# 10    34.240002                    11                 1                0
# 11    65.739998                    11                 1                0
# ...

# %%
# Use the `smf.glm` function to fit `default` to `balance` (hint: use the `binomial` family)
clf = LogisticRegressionCV(cv=5, random_state=0,
                           multi_class='multinomial').fit(X, y)
# glm = smf.glm('Primary.Status_Advanced ~ __features___', data=df, family=sm.families.Binomial()).fit()

# %%
# Ignore this
train_features, test_features, train_outcome, test_outcome = train_test_split(
    dems.drop['Primary.Status_Advanced'],
    data['Primary.Status_',
    test_size = 0.3,
    random_state = 11
)
